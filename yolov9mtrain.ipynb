# %%
# !pip install ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XIPOOjaicevRi4NhZAd1")
project = rf.workspace("vehicle-counter").project("vehicle-counter-5zkt5")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/60/e7/a6dedca760db7a4686fd3b6053487ad4ad4d8f0591295dc8a9cf35269c42/opencv_python_headless-4.8.0.74-cp37-abi3-win_amd64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
# ...
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/58/8b/92421decb23b590d9d0fd68de5531fee619fd509ecdf31c9649f037c6b5e/roboflow-1.1.30-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for certifi==2023.7.22 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
# ...

# %%
pip install --upgrade ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/7b/2e/a676a77c65a854469f08e8ceccb0e47ad87c0a776b0a9b8f834ded85ed6e/ultralytics-8.2.28-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      ----------------------------- ---------- 30.7/41.2 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 41.2/41.2 kB 659.0 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for ultralytics-thop>=0.2.5 from https://files.pythonhosted.org/packages/94/b2/8279f18815e66a7af55531a3c1a4470478c122073b208a82fc9d41db2294/ultralytics_thop-0.2.7-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/779.6 kB ? eta -:--:--
#    ----------------- --------------------- 358.4/779.6 kB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  778.2/779.6 kB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 779.6/779.6 kB 8.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov9c.pt")  # load a pretrained model (recommended for training)
# This might not work as expected
# model = YOLO("use_WongKinYiu/yolov9_train.pt")

# %%
import torch
 
print(f"Is CUDA supported by this system? {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
 
# Storing ID of current CUDA device
cuda_id = torch.cuda.current_device()
print(f"ID of current CUDA device:      {torch.cuda.current_device()}")
       
print(f"Name of current CUDA device:      {torch.cuda.get_device_name(cuda_id)}")
# Out:
# Is CUDA supported by this system? False
# CUDA version: None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 7
#       4 print(f"CUDA version: {torch.version.cuda}")
#       6 # Storing ID of current CUDA device
# ----> 7 cuda_id = torch.cuda.current_device()
#       8 print(f"ID of current CUDA device:      {torch.cuda.current_device()}")
#      10 print(f"Name of current CUDA device:      {torch.cuda.get_device_name(cuda_id)}")
#
# File S:\anaconda3\Lib\site-packages\torch\cuda\__init__.py:787, in current_device()
#     785 def current_device() -> int:
#     786     r"""Return the index of a currently selected device."""
# --> 787     _lazy_init()
#     788     return torch._C._cuda_getDevice()
#
# File S:\anaconda3\Lib\site-packages\torch\cuda\__init__.py:293, in _lazy_init()
#     288     raise RuntimeError(
# ...

# %%
results = model.train(data="S:\college\python\detect/Vehicle-counter-2/data.yaml", epochs=100, imgsz=640, device=0)
# Out:
# Ultralytics YOLOv8.2.28  Python-3.11.5 torch-2.2.2+cpu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 results = model.train(data="S:\college\python\detect/Vehicle-counter-2/data.yaml", epochs=100, imgsz=640, device=0)
#
# File S:\anaconda3\Lib\site-packages\ultralytics\engine\model.py:655, in Model.train(self, trainer, **kwargs)
#     652 if args.get("resume"):
#     653     args["resume"] = self.ckpt_path
# --> 655 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     656 if not args.get("resume"):  # manually set model only if not resuming
#     657     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File S:\anaconda3\Lib\site-packages\ultralytics\engine\trainer.py:101, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
# ...
